# %% [markdown]
# <a href="https://colab.research.google.com/github/joysujeeth1761/cosine_similarity_numpy/blob/main/cosine_similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
#create vectors

A = np.array([1,2,3])
B = np.array([4,5,6])

print ('vector A:',A)
print ('vector B:',B)
# Out:
# vector A: [1 2 3]
# vector B: [4 5 6]

# %%
#Dot product

dot_product = np.dot(A,B)

print('dot product of A and B:', dot_product)
# Out:
# dot product of A and B: 32

# %%
# Norms

norm_A = np.linalg.norm(A)
norm_B = np.linalg.norm(B)

print("Norm of A:", norm_A)
print("Norm of B:", norm_B)
# Out:
# Norm of A: 3.7416573867739413
# Norm of B: 8.774964387392123

# %%
# cosine similarity

cosine_similarity = dot_product / (norm_A * norm_B)
print("Cosine Similarity:", cosine_similarity)
# Out:
# Cosine Similarity: 0.9746318461970762

# %%
# Matrix Shapes

X = np.random.rand(3,4)
W = np.random.rand(4,2)

print('matrix shape of X:', X.shape)
print ('matrix shape of W:', W.shape)
# Out:
# matrix shape of X: (3, 4)
# matrix shape of W: (4, 2)

# %%
# Matrix multiplication

result = np.dot(X,W)

print('matrix multiplication:', result)
# Out:
# matrix multiplication: [[1.25826032 1.33547671]
#  [1.89550068 1.9605245 ]
#  [2.11507099 2.35815515]]
